# %%
import math
import numpy as np 
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def f(x):
    return 3*x**2 - 4*x + 5

# %%
f(3.0)
# Out:
# 20.0

# %%
xs = np.arange(-5, 5, 0.25)
ys = f(xs)
plt.plot(xs, ys)

# %%
h = 0.000001
x = 2/3
(f(x + h) - f(x))/h
# Out:
# 2.999378523327323e-06

# %%
# les get more complex
a = 2.0
b = -3.0
c = 10.0
d = a*b + c
print(d)
